# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!git clone -b "dev" https://github.com/MLsound/KON-Artist/
# !git clone -b "acp" https://github.com/MLsound/KON-Artist/
# Out:
# Cloning into 'KON-Artist'...
# remote: Enumerating objects: 564, done.
# remote: Counting objects: 100% (200/200), done.
# remote: Compressing objects: 100% (115/115), done.
# remote: Total 564 (delta 105), reused 150 (delta 73), pack-reused 364 (from 1)
# Receiving objects: 100% (564/564), 26.94 MiB | 24.80 MiB/s, done.
# Resolving deltas: 100% (278/278), done.

# %%
# %cd /content/KON-Artist
# Out:
# /content/KON-Artist

# %%
ROOT_PATH = "/content/KON-Artist"

# %%
# Removes previous results (avoids moving unnecesary data)
# %rm -rf outputs/

# %%
# Re-create output folders
# !mkdir outputs/
# !mkdir outputs/history/
# !mkdir outputs/checkpoints/

# %%
# !git clone https://github.com/mtuciru/AASIST3.git third_party/AASIST3
# Out:
# Cloning into 'third_party/AASIST3'...
# remote: Enumerating objects: 73, done.
# remote: Counting objects: 100% (73/73), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 73 (delta 25), reused 66 (delta 22), pack-reused 0 (from 0)
# Receiving objects: 100% (73/73), 37.58 KiB | 3.76 MiB/s, done.
# Resolving deltas: 100% (25/25), done.

# %% [markdown]
# ---

# %%
# !pip install --quiet \
    numpy==1.26.4 scipy==1.13.1 pandas==2.3.3 \
    torch==2.2.2 torchaudio==2.2.2 torchvision==0.17.2 \
    stable-baselines3==2.4.1 gymnasium==1.0.0 \
    librosa==0.11.0 soundfile==0.13.1 \
    matplotlib==3.10.8 transformers==4.40.0 \
    datasets==2.19.1 huggingface-hub==0.36.2 pyyaml

# %%
# !python -m src.data.clustering
# Out:
# [2026-06-04 17:19:24] INFO [aasist:53] Successfully imported aasist3 from the AASIST3 repository.
# config.json: 100% 550/550 [00:00<00:00, 4.66MB/s]
# config.json: 1.77kB [00:00, 10.5MB/s]
# model.safetensors: 100% 1.29G/1.29G [00:11<00:00, 113MB/s]
# [2026-06-04 17:19:42] INFO [aasist:68] Loaded AASIST3 model from Hugging Face: MTUCI/AASIST3
# [2026-06-04 17:19:43] INFO [aasist:39] AASIST3 model loaded on cuda
# ...
# [2026-06-04 17:19:45] INFO [clustering:51] Starting batched embedding extraction (batch_size=64, max_samples=10000)...
# Extracting embeddings: 100% 10000/10000 [18:07<00:00,  9.20it/s]
# [2026-06-04 17:37:52] INFO [clustering:166] Extracted 10000 embeddings of dimension 160.
# [2026-06-04 17:37:52] INFO [clustering:94] Optimizing clustering parameters...
# [2026-06-04 17:37:52] INFO [clustering:106] Optimal PCA components (95% variance): 4
# [2026-06-04 17:37:54] INFO [clustering:121] Optimal GMM components (Lowest BIC): 10
# ...

# %%
from google.colab import files

# Download the trained GMM registry
files.download('models/gmm_registry.pkl')

# Download the visualization plots
files.download('outputs/plots/clustering_optimization.png')
files.download('outputs/plots/acoustic_clusters_tsne.png')
